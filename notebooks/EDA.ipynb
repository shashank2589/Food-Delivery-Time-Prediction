# %%
import pandas as pd

# %%
df = pd.read_csv("data/finalTrain.csv")

# %%
df.head(10)
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
# 5  0x3af3      MUMRES15DEL03                 29.0                      4.5
# 6  0x3aab      MYSRES01DEL01                 35.0                      4.0
# 7  0x689b     PUNERES20DEL01                 33.0                      4.2
# 8  0x6f67      HYDRES14DEL01                 34.0                      4.9
# 9  0xc9cf      KOLRES15DEL03                 21.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
# 5            19.176269             72.836721                   19.266269
# 6            12.311072             76.654878                   12.351072
# 7            18.592718             73.773572                   18.702718
# 8            17.426228             78.407495                   17.496228
# 9            22.552672             88.352885                   22.582672
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# 0                    78.116106  12-02-2022       21:55             22:10  \
# 1                    76.347589  13-02-2022       14:55             15:05
# 2                    74.006619  04-03-2022       17:30             17:40
# 3                    75.829346  13-02-2022       09:20             09:30
# 4                    80.502929  14-02-2022       19:50             20:05
# 5                    72.926721  02-04-2022       20:25             20:35
# 6                    76.694878  01-03-2022       14:55             15:10
# 7                    73.883572  16-03-2022       20:30             20:40
# 8                    78.477495  20-03-2022       20:40             20:50
# 9                    88.382885  15-02-2022       21:15             21:30
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order
# 0                Fog                  Jam                  2         Snack  \
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
# 5         Sandstorms                  Jam                  2        Buffet
# 6              Windy                 High                  1          Meal
# 7         Sandstorms                  Jam                  2         Snack
# 8             Cloudy                  Jam                  0         Snack
# 9              Windy                  Jam                  0          Meal
#
#     Type_of_vehicle  multiple_deliveries Festival           City
# 0        motorcycle                  3.0       No  Metropolitian  \
# 1        motorcycle                  1.0       No  Metropolitian
# 2           scooter                  1.0       No  Metropolitian
# 3        motorcycle                  0.0       No  Metropolitian
# 4           scooter                  1.0       No  Metropolitian
# 5  electric_scooter                  1.0       No  Metropolitian
# 6           scooter                  1.0       No  Metropolitian
# 7        motorcycle                  1.0       No  Metropolitian
# 8        motorcycle                  NaN       No  Metropolitian
# 9        motorcycle                  1.0       No          Urban
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41
# 5                20
# 6                33
# 7                40
# 8                41
# 9                15

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
#  12  Road_traffic_density         44983 non-null  object
#  13  Vehicle_condition            45584 non-null  int64
#  14  Type_of_order                45584 non-null  object
#  15  Type_of_vehicle              45584 non-null  object
#  16  multiple_deliveries          44591 non-null  float64
#  17  Festival                     45356 non-null  object
#  18  City                         44384 non-null  object
#  19  Time_taken (min)             45584 non-null  int64
# dtypes: float64(7), int64(2), object(11)
# memory usage: 7.0+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.dropna(subset=["Time_Orderd"])

# %%
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age             214
# Delivery_person_Ratings         268
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                       0
# Time_Order_picked                 0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             943
# Festival                        219
# City                           1144
# Time_taken (min)                  0
# dtype: int64

# %%
df.shape
# Out:
# (43853, 20)

# %%
df = df.drop(["ID", "Delivery_person_ID"], axis = 1)

# %%
df.tail()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 45579                 30.0                      4.8            26.902328  \
# 45580                 21.0                      4.6             0.000000
# 45581                 30.0                      4.9            13.022394
# 45582                 20.0                      4.7            11.001753
# 45583                 23.0                      4.9            23.351058
#
#        Restaurant_longitude  Delivery_location_latitude
# 45579             75.794257                   26.912328  \
# 45580              0.000000                    0.070000
# 45581             80.242439                   13.052394
# 45582             76.986241                   11.041753
# 45583             85.325731                   23.431058
#
#        Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# 45579                    75.804257  24-03-2022       11:35             11:45  \
# 45580                     0.070000  16-02-2022       19:55             20:10
# 45581                    80.272439  11-03-2022       23:50          24:05:00
# 45582                    77.026241  07-03-2022       13:35             13:40
# 45583                    85.405731  02-03-2022       17:10             17:15
#
#       Weather_conditions Road_traffic_density  Vehicle_condition
# 45579              Windy                 High                  1  \
# 45580              Windy                  Jam                  0
# 45581             Cloudy                  Low                  1
# 45582             Cloudy                 High                  0
# 45583                Fog               Medium                  2
#
#       Type_of_order Type_of_vehicle  multiple_deliveries Festival
# 45579          Meal      motorcycle                  0.0       No  \
# 45580        Buffet      motorcycle                  1.0       No
# 45581        Drinks         scooter                  0.0       No
# 45582         Snack      motorcycle                  1.0       No
# 45583         Snack         scooter                  1.0       No
#
#                 City  Time_taken (min)
# 45579  Metropolitian                32
# 45580  Metropolitian                36
# 45581  Metropolitian                16
# 45582  Metropolitian                26
# 45583  Metropolitian                36

# %%
df['Time_Order_picked'].unique()
# Out:
# array(['22:10', '15:05', '17:40', '09:30', '20:05', '20:35', '15:10',
#        '20:40', '20:50', '21:30', '20:25', '22:45', '08:30', '19:45',
#        '12:30', '18:50', '23:30', '21:35', '23:45', '22:50', '22:40',
#        '23:35', '13:40', '21:45', '19:10', '14:25', '11:10', '09:55',
#        '08:55', '23:10', '17:30', '19:50', '19:25', '0.458333333',
#        '19:15', '16:55', '11:40', '15:15', '22:55', '22:25', '20:55',
#        '23:05', '0.75', '0.958333333', '09:40', '20:20', '22:35',
#        '0.916666667', '23:55', '15:40', '10:30', '0.875', '10:50',
#        '16:05', '20:15', '12:15', '15:45', '22:15', '10:45', '24:05:00',
#        '21:25', '12:45', '21:15', '18:20', '18:25', '11:50', '12:50',
#        '10:55', '21:40', '10:20', '17:55', '23:50', '12:55', '24:10:00',
#        '10:40', '0.375', '20:45', '0.833333333', '23:15', '18:35',
#        '22:20', '21:05', '0.708333333', '24:15:00', '21:20', '14:35',
#        '10:25', '09:05', '16:50', '08:40', '23:40', '21:50', '19:55',
#        '0.625', '10:35', '09:25', '17:20', '19:30', '17:25', '20:10', '1',
#        '17:35', '0.791666667', '19:05', '13:20', '18:05', '19:20',
#        '10:05', '09:10', '21:55', '19:40', '18:10', '09:50', '15:50',
#        '18:30', '18:15', '16:15', '11:15', '21:10', '15:30', '22:30',
#        '15:20', '18:40', '23:20', '11:25', '13:55', '18:45', '22:05',
#        '11:55', '18:55', '09:45', '17:15', '12:05', '0.5', '19:35',
#        '08:25', '11:05', '15:35', '12:40', '12:25', '08:20', '23:25',
#        '16:10', '17:50', '13:45', '08:15', '08:45', '20:30', '11:20',
#        '08:50', '14:45', '17:45', '0.416666667', '08:35', '11:35',
#        '14:30', '12:10', '10:15', '17:05', '10:10', '09:35', '11:30',
#        '16:25', '09:15', '13:35', '15:55', '0.541666667', '13:10',
#        '13:05', '11:45', '16:20', '16:30', '16:45', '09:20', '13:25',
#        '14:15', '16:35', '16:40', '14:05', '13:30', '14:40', '12:20',
#        '13:50', '17:10', '14:20', '12:35', '0.583333333', '14:10',
#        '15:25', '14:55', '13:15', '14:50', '0.666666667'], dtype=object)

# %%
df['Time_Orderd'].unique()
# Out:
# array(['21:55', '14:55', '17:30', '09:20', '19:50', '20:25', '20:30',
#        '20:40', '21:15', '20:20', '22:30', '08:15', '19:30', '12:25',
#        '18:35', '20:35', '23:20', '21:20', '23:35', '22:35', '23:25',
#        '13:35', '21:35', '18:55', '14:15', '0.458333333', '09:45',
#        '08:40', '0.958333333', '17:25', '19:45', '19:10', '10:55',
#        '21:40', '0.791666667', '16:45', '11:30', '15:10', '22:45',
#        '22:10', '20:45', '22:50', '17:55', '09:25', '20:15', '22:25',
#        '22:40', '23:50', '15:25', '10:20', '20:55', '10:40', '15:55',
#        '20:10', '12:10', '15:30', '10:35', '21:10', '20:50', '12:35',
#        '0.875', '23:40', '18:15', '18:20', '11:45', '12:45', '23:30',
#        '10:50', '21:25', '10:10', '17:50', '22:20', '12:40', '23:55',
#        '10:25', '08:45', '23:45', '19:55', '22:15', '23:10', '09:15',
#        '18:25', '18:45', '16:50', '1', '14:20', '10:15', '08:50', '0.375',
#        '17:45', '16:35', '08:30', '21:45', '19:40', '14:50', '18:10',
#        '12:20', '12:50', '09:10', '12:30', '17:10', '19:15', '17:20',
#        '18:30', '13:10', '19:35', '09:50', '0.625', '0.833333333',
#        '10:30', '09:40', '15:35', '16:55', '22:55', '0.666666667', '0.75',
#        '17:15', '21:30', '18:40', '11:10', '13:50', '0.416666667',
#        '21:50', '11:50', '13:30', '0.916666667', '08:25', '11:20',
#        '11:55', '09:30', '08:20', '08:10', '11:40', '23:15', '19:20',
#        '12:15', '11:35', '11:15', '17:35', '17:40', '14:40', '18:50',
#        '11:25', '14:25', '0.5', '16:10', '19:25', '08:55', '13:40',
#        '0.708333333', '09:35', '08:35', '16:15', '13:20', '15:50',
#        '15:20', '16:20', '14:30', '15:45', '16:40', '0.541666667',
#        '12:55', '10:45', '13:25', '09:55', '15:15', '13:15',
#        '0.583333333', '15:40', '16:25', '14:10', '13:45', '13:55',
#        '14:35', '16:30', '14:45'], dtype=object)

# %%
df['Time_Order_picked'] = df['Time_Order_picked'].replace({'0.458333333': '11:00', '0.75' : '18:00', '0.958333333' : '23:00', '0.916666667': '22:00', '0.875' : '21:00', '24:05:00': '00:05', '24:10:00' : '00:10', '0.375' :'09:00', '0.833333333' : '20:00' , '0.708333333': '17:00', '24:15:00': '00:15', '0.625': '15:00', '1': '00:00','0.791666667': '19:00', '0.5' : '12:00', '0.416666667': '10:00', '0.541666667': '13:00', '0.583333333': '14:00', '0.666666667': '16:00'})
df['Time_Orderd'] = df['Time_Orderd'].replace({'0.458333333': '11:00', '0.958333333' : '23:00', '0.791666667': '19:00', '0.875' : '21:00', '1': '00:00', '0.375' :'09:00', '0.625': '15:00', '0.833333333' : '20:00', '0.666666667': '16:00', '0.75' : '18:00', '0.416666667': '10:00', '0.916666667': '22:00', '0.5' : '12:00', '0.708333333': '17:00', '0.541666667': '13:00', '0.583333333': '14:00'})

# %%
df['Order_datetime'] = pd.to_datetime(df['Order_Date'] + ' ' + df['Time_Orderd'], format='%d-%m-%Y %H:%M')
df['picked_datetime'] = pd.to_datetime(df['Order_Date'] + ' ' + df['Time_Order_picked'], format='%d-%m-%Y %H:%M')

# %%
df['preparation_time'] = df["picked_datetime"] - df['Order_datetime']
df = df.drop(["Order_Date", "Time_Orderd", "Time_Order_picked"], axis = 1)

# %%
df.describe().T
# Out:
#                                count                           mean
# Delivery_person_Age          43639.0                      29.554779  \
# Delivery_person_Ratings      43585.0                        4.63528
# Restaurant_latitude          43853.0                      17.242245
# Restaurant_longitude         43853.0                      70.763328
# Delivery_location_latitude   43853.0                      17.462771
# Delivery_location_longitude  43853.0                      70.826921
# Vehicle_condition            43853.0                       1.000912
# multiple_deliveries          42910.0                       0.744092
# Time_taken (min)             43853.0                      26.293161
# Order_datetime                 43853  2022-03-14 10:32:04.486352128
# picked_datetime                43853  2022-03-14 10:14:46.584726016
# preparation_time               43853    -1 days +23:42:42.098374114
#
#                                              min                  25%
# Delivery_person_Age                         20.0                 25.0  \
# Delivery_person_Ratings                      2.5                  4.5
# Restaurant_latitude                   -30.902872            12.933298
# Restaurant_longitude                         0.0            73.170283
# Delivery_location_latitude                  0.01            12.986229
# Delivery_location_longitude                 0.01            73.279083
# Vehicle_condition                            0.0                  0.0
# multiple_deliveries                          0.0                  0.0
# Time_taken (min)                            10.0                 19.0
# Order_datetime               2022-02-11 00:00:00  2022-03-04 23:00:00
# picked_datetime              2022-02-11 00:00:00  2022-03-04 23:00:00
# preparation_time               -1 days +00:05:00      0 days 00:05:00
#
#                                              50%                  75%
# Delivery_person_Age                         30.0                 35.0  \
# Delivery_person_Ratings                      4.7                  4.9
# Restaurant_latitude                    18.554382            22.732225
# Restaurant_longitude                   75.898497            78.045359
# Delivery_location_latitude             18.633934            22.785049
# Delivery_location_longitude             75.99949            78.103162
# Vehicle_condition                            1.0                  2.0
# multiple_deliveries                          1.0                  1.0
# Time_taken (min)                            26.0                 32.0
# Order_datetime               2022-03-15 17:10:00  2022-03-27 18:25:00
# picked_datetime              2022-03-15 17:00:00  2022-03-27 18:20:00
# preparation_time                 0 days 00:10:00      0 days 00:15:00
#
#                                              max                     std
# Delivery_person_Age                         39.0                5.761378
# Delivery_person_Ratings                      5.0                0.313851
# Restaurant_latitude                    30.914057                  7.6992
# Restaurant_longitude                   88.433452               21.138033
# Delivery_location_latitude             31.054057                7.338998
# Delivery_location_longitude            88.563452               21.138202
# Vehicle_condition                            2.0                0.816543
# multiple_deliveries                          3.0                0.572606
# Time_taken (min)                            54.0                9.374274
# Order_datetime               2022-04-06 23:55:00                     NaN
# picked_datetime              2022-04-06 23:55:00                     NaN
# preparation_time                 0 days 00:15:00  0 days 03:16:08.345271

# %%
drop_feature = df[df['Restaurant_latitude'] == 0.0].index

# %%
df = df.drop(drop_feature, axis = 0)
df.shape
# Out:
# (40344, 18)

# %%
df.dtypes
# Out:
# Delivery_person_Age                    float64
# Delivery_person_Ratings                float64
# Restaurant_latitude                    float64
# Restaurant_longitude                   float64
# Delivery_location_latitude             float64
# Delivery_location_longitude            float64
# Weather_conditions                      object
# Road_traffic_density                    object
# Vehicle_condition                        int64
# Type_of_order                           object
# Type_of_vehicle                         object
# multiple_deliveries                    float64
# Festival                                object
# City                                    object
# Time_taken (min)                         int64
# Order_datetime                  datetime64[ns]
# picked_datetime                 datetime64[ns]
# preparation_time               timedelta64[ns]
# dtype: object

# %%
import numpy as np

# Calculate the distance between the restaurant and the delivery location using the Haversine formula
R = 6371  # Radius of the Earth in kilometers
lat1, lon1 = np.radians(df[['Restaurant_latitude', 'Restaurant_longitude']].values.T)
lat2, lon2 = np.radians(df[['Delivery_location_latitude', 'Delivery_location_longitude']].values.T)

delta_lat = lat2 - lat1
delta_lon = lon2 - lon1

a = np.sin(delta_lat/2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(delta_lon/2) ** 2
c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))

distance = R * c  # distance in kilometers

# Add the distance column to the dataframe
df['distance'] = distance

# %%
df = df.drop(["Restaurant_latitude", "Restaurant_longitude", "Delivery_location_latitude", "Delivery_location_longitude", "Order_datetime","picked_datetime"], axis = 1)

# %%
df.tail()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings Weather_conditions
# 45578                 35.0                      4.2              Windy  \
# 45579                 30.0                      4.8              Windy
# 45581                 30.0                      4.9             Cloudy
# 45582                 20.0                      4.7             Cloudy
# 45583                 23.0                      4.9                Fog
#
#       Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle
# 45578                  Jam                  2        Drinks      motorcycle  \
# 45579                 High                  1          Meal      motorcycle
# 45581                  Low                  1        Drinks         scooter
# 45582                 High                  0         Snack      motorcycle
# 45583               Medium                  2         Snack         scooter
#
#        multiple_deliveries Festival           City  Time_taken (min)
# 45578                  1.0       No  Metropolitian                33  \
# 45579                  0.0       No  Metropolitian                32
# 45581                  0.0       No  Metropolitian                16
# 45582                  1.0       No  Metropolitian                26
# 45583                  1.0       No  Metropolitian                36
#
#        preparation_time   distance
# 45578   0 days 00:10:00  16.600272
# 45579   0 days 00:10:00   1.489846
# 45581 -1 days +00:15:00   4.657195
# 45582   0 days 00:05:00   6.232393
# 45583   0 days 00:05:00  12.074396

# %%
df["preparation_time"] = df["preparation_time"].dt.components.minutes
df.head(3)
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Weather_conditions
# 0                 36.0                      4.2                Fog  \
# 1                 21.0                      4.7             Stormy
# 2                 23.0                      4.7         Sandstorms
#
#   Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle
# 0                  Jam                  2         Snack      motorcycle  \
# 1                 High                  1          Meal      motorcycle
# 2               Medium                  1        Drinks         scooter
#
#    multiple_deliveries Festival           City  Time_taken (min)
# 0                  3.0       No  Metropolitian                46  \
# 1                  1.0       No  Metropolitian                23
# 2                  1.0       No  Metropolitian                21
#
#    preparation_time   distance
# 0                15  10.280582
# 1                10   6.242319
# 2                10  13.787860

# %%
numeric_data = ['Vehicle_condition','multiple_deliveries', 'preparation_time']
numeric_data1 = ['Delivery_person_Age','Delivery_person_Ratings', 'distance', "Time_taken (min)"]

# %%
categorical_data = [col for col in df.columns if df[col].dtypes == "O"]
categorical_data
# Out:
# ['Weather_conditions',
#  'Road_traffic_density',
#  'Type_of_order',
#  'Type_of_vehicle',
#  'Festival',
#  'City']

# %%
df.describe().T
# Out:
#                            count       mean         std        min        25%
# Delivery_person_Age      40144.0  29.552361    5.760808  20.000000  25.000000  \
# Delivery_person_Ratings  40100.0   4.633980    0.314914   2.500000   4.500000
# Vehicle_condition        40344.0   0.999901    0.816203   0.000000   0.000000
# multiple_deliveries      39489.0   0.744587    0.572311   0.000000   0.000000
# Time_taken (min)         40344.0  26.311918    9.371971  10.000000  19.000000
# preparation_time         40344.0   9.978435    4.087331   5.000000   5.000000
# distance                 40344.0  28.673485  315.965666   1.465067   4.657673
#
#                                50%        75%          max
# Delivery_person_Age      30.000000  35.000000    39.000000
# Delivery_person_Ratings   4.700000   4.900000     5.000000
# Vehicle_condition         1.000000   2.000000     2.000000
# multiple_deliveries       1.000000   1.000000     3.000000
# Time_taken (min)         26.000000  32.000000    54.000000
# preparation_time         10.000000  15.000000    15.000000
# distance                  9.206322  13.681487  6884.726399

# %%
q1 = df["distance"].quantile(0.25)
q3 = df["distance"].quantile(0.75)
iqr = q3 - q1
upper = q3 + 1.5*iqr
lower = q1 - 1.5*iqr
outliers = df[(df["distance"] > upper) | (df["distance"] < lower)].index
print("Range:", upper , lower)
# Out:
# Range: 27.217208957404054 -8.878049133444762

# %%
outliers
# Out:
#        Delivery_person_Age  Delivery_person_Ratings Weather_conditions
# 83                    34.0                      4.7         Sandstorms  \
# 274                   32.0                      4.7         Sandstorms
# 1082                  20.0                      4.7             Cloudy
# 1774                  39.0                      4.5             Cloudy
# 1967                  25.0                      4.0         Sandstorms
# ...                    ...                      ...                ...
# 43851                 32.0                      4.6         Sandstorms
# 44042                 22.0                      5.0         Sandstorms
# 44631                 23.0                      4.8              Sunny
# 44924                 30.0                      4.9                Fog
# 45173                 30.0                      4.0         Sandstorms
#
#       Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle
# 83                     Low                  1        Drinks         scooter  \
# 274                    Jam                  2          Meal         scooter
# 1082                   Jam                  2        Drinks      motorcycle
# 1774                   Low                  0          Meal      motorcycle
# 1967                   Low                  0        Buffet      motorcycle
# ...                    ...                ...           ...             ...
# 43851                  Low                  0         Snack      motorcycle
# 44042               Medium                  1        Buffet         scooter
# 44631                  Jam                  0        Drinks      motorcycle
# 44924                  Low                  1        Buffet      motorcycle
# 45173                  Low                  0        Drinks      motorcycle
#
#        multiple_deliveries Festival           City  Time_taken (min)
# 83                     0.0       No  Metropolitian                15  \
# 274                    1.0       No  Metropolitian                31
# 1082                   1.0       No  Metropolitian                29
# 1774                   1.0       No  Metropolitian                29
# 1967                   0.0       No  Metropolitian                19
# ...                    ...      ...            ...               ...
# 43851                  1.0       No  Metropolitian                24
# 44042                  1.0       No  Metropolitian                27
# 44631                  1.0       No  Metropolitian                21
# 44924                  0.0       No  Metropolitian                15
# 45173                  1.0       No  Metropolitian                34
#
#        preparation_time     distance
# 83                    5  6048.631240
# 274                  15  6047.919478
# 1082                 10  3464.082720
# 1774                  5  5168.516553
# 1967                  5  5013.585658
# ...                 ...          ...
# 43851                 5  3454.524245
# 44042                 5  3377.651072
# 44631                15  2230.110757
# 44924                15  4423.276011
# 45173                15  5895.019482
#
# [156 rows x 13 columns]

# %%
df = df.drop(outliers)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15,15))
plt.suptitle("Univariate Analysis of Numerical Data", fontsize = 20, fontweight = "bold", alpha = 0.8, y=1)

for i in range(0, len(numeric_data)):
    plt.subplot(5, 3, i+1)
    sns.boxplot(x = df[numeric_data[i]], y='Time_taken (min)', data=df)
    plt.xlabel(numeric_data[i])
    plt.tight_layout()

# %%
sns.lmplot(x='Delivery_person_Age', y='Time_taken (min)', data=df)
plt.title('Scatter plot of Delivery_person_Age vs Time_taken with Trendline')
plt.show()

# %%
sns.lmplot(x='Delivery_person_Ratings', y='Time_taken (min)', data=df)
plt.title('Scatter plot of Delivery_person_Ratings vs Time_taken with Trendline')
plt.show()

# %%
sns.lmplot(x='distance', y='Time_taken (min)', data=df)
plt.title('Scatter plot of distance vs Time_taken with Trendline')
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.suptitle("Univariate Analysis of Numerical Data", fontsize = 20, fontweight = "bold", alpha = 0.8, y=1)

for i in range(0, len(numeric_data1)):
    plt.subplot(5, 4, i+1)
    sns.kdeplot(x = df[numeric_data1[i]], fill =True, color='purple')
    plt.xlabel(numeric_data1[i])
    plt.tight_layout()

# %%
plt.figure(figsize=(20,25))
plt.suptitle("Univariate Analysis of Categorical Data", fontsize = 25, fontweight = "bold", alpha = 0.8, y=1)

for i in range(0, len(categorical_data)):
    plt.subplot(5, 3, i+1)
    sns.boxplot(x = df[categorical_data[i]], y='Time_taken (min)', data=df)
    plt.xlabel(categorical_data[i])
    plt.xticks(rotation = 90)
    plt.tight_layout()

# %%
corr = df.corr(numeric_only = True)
corr_with_target = corr['Time_taken (min)'].sort_values(ascending=False)
print(corr_with_target)
# Out:
# Time_taken (min)           1.000000
# multiple_deliveries        0.387186
# distance                   0.321341
# Delivery_person_Age        0.303591
# preparation_time          -0.009617
# Vehicle_condition         -0.242708
# Delivery_person_Ratings   -0.362414
# Name: Time_taken (min), dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True)
plt.show()

# %%
df['Festival'] = df['Festival'].map({'Yes': 1, 'No': 0})

# %%
df=df.drop(labels=['Type_of_order', 'Type_of_vehicle', 'preparation_time'],axis=1)

# %%
df.to_csv("data/clean_data.csv", index=False)
